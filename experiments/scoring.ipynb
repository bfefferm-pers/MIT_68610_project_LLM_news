# %%
import pandas as pd
import numpy as np
import os

from score import compute_pbf_score

labels = {
    'left': -1,
    'center': 0,
    'right': 1
}

input_dir = '../summaries/'

SUPPORTED_MODELS = ['bart', 't5', 'gpt2', 'neo', 'llama']
NUM_SUMMARIES = 900

def split_pred_by_stance(df_steered, k=3):
    '''
    Splits predictions in given dataframe by steering stance,
    which repeats in a sequence of 'left', 'right', and 'center's.
    '''
    stances = {'left': [], 'right': [], 'center': []}

    num_summaries_per_stance = df_steered.shape[0] // k
    assert num_summaries_per_stance == 900, "expecting 900 summaries per stance"

    for i in range(num_summaries_per_stance):
        stance = df_steered.iloc[i*k]['Stance']
        pred = [labels[df_steered.iloc[i*k + j]['Predicted Bias']] for j in range(k)]
        stances[stance].append(pred)

    left, right, center = stances['left'], stances['right'], stances['center']
    len(left) == len(right) == len(center) == 300, "expecting 300 (groups of) predictions per stance"

    return left, right, center

def split_pred_by_matching(df_steered, source_bias, k=3):
    """
    Splits predictions into two categories based on whether their
    steer stance match the source bias.
    """
    match_source, match_pred = [], []
    mismatch_source, mismatch_pred = [], []

    num_summaries_per_stance = df_steered.shape[0] // k

    for i in range(num_summaries_per_stance):
        pred = [labels[df_steered.iloc[i * k + j]['Predicted Bias']] for j in range(k)]
        steer_stance = labels[df_steered.iloc[i * k]['Stance']]
        source_stance = source_bias[i//k]

        if steer_stance == source_stance:
            match_source.append(source_stance)
            match_pred.append(pred)
        else:
            mismatch_source.append(source_stance)
            mismatch_pred.append(pred)

    return match_source, match_pred, mismatch_source, mismatch_pred


def get_stances(df, k=3):
    true, pred = [], []

    for i in range(0, df.shape[0], k):
        true.append(labels[df.iloc[i]['Stance']])
        group = [labels[df.iloc[i+j]['Predicted Bias']] for j in range(k)]
        pred.append(group)

    return true, pred


def matches(lst1, lst2):
    return sum(y.count(x) for x, y in zip(lst1, lst2)) / (len(lst1) * 3)


def process_summaries(model, k=3):
    if model not in ['bart', 't5', 'gpt2', 'neo', 'llama']:
        return

    print(f'Processing summaries for {model}...')

    path = os.path.join(input_dir, f'{model}.csv')
    df = pd.read_csv(path)
    print(f'\tLoaded {path} with {df.shape[0]} summaries.')

    path_steered  = os.path.join(input_dir, f'{model}-prompt.csv')
    df_steered = pd.read_csv(path_steered)
    print(f'\tLoaded {path_steered} with {df_steered.shape[0]} summaries.')

    print('\n')

    # without steering intervention
    true, pred = get_stances(df)
    pbf = compute_pbf_score(np.array(true), np.array(pred))
    print(f' - percentage matching with steering: {matches(true,pred)}')
    print(f' - PBF score without steering: {pbf}')

    print('\n')

    # with steering intervention
    target, pred_steered = get_stances(df_steered)
    pbf_steered = compute_pbf_score(np.array(target), np.array(pred_steered))
    print(f' - percentage matching with steering (ALL): {matches(target,pred_steered)}')
    print(f' - PBF score with steering (ALL): {pbf_steered}')

    pred_left, pred_right, pred_center = split_pred_by_stance(df_steered)

    left = [labels['left']]*len(pred_left)
    pbf_left = compute_pbf_score(np.array(left), np.array(pred_left))
    print(f'\t - percentage matching with steering (LEFT): {matches(left,pred_left)}')
    print(f'\t - PBF score with steering (LEFT): {pbf_left}')

    center = [labels['center']]*len(pred_center)
    pbf_center = compute_pbf_score(np.array(center), np.array(pred_center))
    print(f'\t - percentage matching with steering (CENTER): {matches(center,pred_center)}')
    print(f'\t - PBF score with steering (CENTER): {pbf_center}')

    right = [labels['right']]*len(pred_right)
    pbf_right = compute_pbf_score(np.array(right), np.array(pred_right))
    print(f'\t - percentage matching with steering (RIGHT): {matches(right,pred_right)}')
    print(f'\t - PBF score with steering (RIGHT): {pbf_right}')

    print('\n')

    source = [labels[df.iloc[i]['Stance']] for i in range(0, df.shape[0], k)]
    match_source, match_pred, mismatch_source, mismatch_pred = split_pred_by_matching(df_steered, source)

    pbf_match = compute_pbf_score(np.array(match_source), np.array(match_pred))
    print(f' - PBF score with steering, where target bias matches source bias: {pbf_match}')

    pbf_mismatch = compute_pbf_score(np.array(mismatch_source), np.array(mismatch_pred))
    print(f' - PBF score with steering, where target bias does *not* match source bias: {pbf_mismatch}')

    print('\n--------------------\n')


def process_no_intervention(model):
    """
    Processes the no intervention results for a given model.

    Args:
    model (str): The name of the model to be processed.
    """
    if model not in SUPPORTED_MODELS:
        print(f"Model '{model}' is not supported.")
        return

    print(f'Processing no intervention results for {model}...')
    path = os.path.join(input_dir, f'{model}.csv')
    df = pd.read_csv(path)
    print(f'\tLoaded {path} with {df.shape[0]} summaries.')

    true_stances, predicted_stances = get_stances(df)

    counter = dict.fromkeys(['left', 'center', 'right'], 0)

    for true, predictions in zip(true_stances, predicted_stances):
        for prediction in predictions:
            difference = prediction - true
            if difference < 0:
                counter['left'] += 1
            elif difference > 0:
                counter['right'] += 1
            else:
                counter['center'] += 1

    for direction in ['left', 'right', 'center']:
        print(f'\tShifted {direction}: {counter[direction] / NUM_SUMMARIES}')


def process(model, k=3, intervention='prompt'):
    if model not in ['bart', 't5', 'gpt2', 'neo', 'llama']:
        return

    print(f'Processing summaries for {model}...')

    path = os.path.join(input_dir, f'{model}.csv')
    df = pd.read_csv(path)
    print(f'\tLoaded {path} with {df.shape[0]} summaries.')

    path_steered  = os.path.join(input_dir, f'{model}-{intervention}.csv')
    df_steered = pd.read_csv(path_steered)
    print(f'\tLoaded {path_steered} with {df_steered.shape[0]} summaries.')

    print('\n')

    # without steering intervention
    true, pred = get_stances(df)
    pbf = compute_pbf_score(np.array(true), np.array(pred))
    print(f' - percentage matching with steering: {matches(true,pred)}')
    print(f' - PBF score without steering: {pbf}')

    print('\n')

    # with steering intervention
    target, pred_steered = get_stances(df_steered)
    pbf_steered = compute_pbf_score(np.array(target), np.array(pred_steered))
    print(f' - percentage matching with steering (ALL): {matches(target,pred_steered)}')
    print(f' - PBF score with steering (ALL): {pbf_steered}')

    pred_left, pred_right, pred_center = split_pred_by_stance(df_steered, k=3)

    left = [labels['left']]*len(pred_left)
    pbf_left = compute_pbf_score(np.array(left), np.array(pred_left))
    print(f'\t - percentage matching with steering (LEFT): {matches(left,pred_left)}')
    print(f'\t - PBF score with steering (LEFT): {pbf_left}')

    center = [labels['center']]*len(pred_center)
    pbf_center = compute_pbf_score(np.array(center), np.array(pred_center))
    print(f'\t - percentage matching with steering (CENTER): {matches(center,pred_center)}')
    print(f'\t - PBF score with steering (CENTER): {pbf_center}')

    right = [labels['right']]*len(pred_right)
    pbf_right = compute_pbf_score(np.array(right), np.array(pred_right))
    print(f'\t - percentage matching with steering (RIGHT): {matches(right,pred_right)}')
    print(f'\t - PBF score with steering (RIGHT): {pbf_right}')

    print('\n')

    source = [labels[df.iloc[i]['Stance']] for i in range(0, df.shape[0], k)]
    match_source, match_pred, mismatch_source, mismatch_pred = split_pred_by_matching(df_steered, source)

    pbf_match = compute_pbf_score(np.array(match_source), np.array(match_pred))
    print(f' - PBF score with steering, where target bias matches source bias: {pbf_match}')

    pbf_mismatch = compute_pbf_score(np.array(mismatch_source), np.array(mismatch_pred))
    print(f' - PBF score with steering, where target bias does *not* match source bias: {pbf_mismatch}')

    print('\n--------------------\n')

# %%
process('neo', k=3, intervention='smc')
# Out:
# Processing summaries for neo...
# 	Loaded ../summaries/neo.csv with 900 summaries.
# 	Loaded ../summaries/neo-smc.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.4177777777777778
#  - PBF score without steering: 0.5420456111988639
#
#
#  - percentage matching with steering (ALL): 0.5792592592592593
#  - PBF score with steering (ALL): 0.5755177445579318
# 	 - percentage matching with steering (LEFT): 0.6211111111111111
# 	 - PBF score with steering (LEFT): 0.5931148128088766
# 	 - percentage matching with steering (CENTER): 0.6266666666666667
# 	 - PBF score with steering (CENTER): 0.6944949536696107
# 	 - percentage matching with steering (RIGHT): 0.49
# 	 - PBF score with steering (RIGHT): 0.469277222396978
#
#
#  - PBF score with steering, where target bias matches source bias: 0.6059469860821037
#  - PBF score with steering, where target bias does *not* match source bias: 0.4327209191627498
#
# --------------------

# %%
for model in ['bart', 't5', 'gpt2', 'neo', 'llama']:
    process_no_intervention(model)
# Out:
# Processing no intervention results for bart...
# 	Loaded ../summaries/bart.csv with 900 summaries.
# 	Shifted left: 0.23
# 	Shifted right: 0.36777777777777776
# 	Shifted center: 0.4022222222222222
# Processing no intervention results for t5...
# 	Loaded ../summaries/t5.csv with 900 summaries.
# 	Shifted left: 0.46444444444444444
# 	Shifted right: 0.23333333333333334
# 	Shifted center: 0.3022222222222222
# Processing no intervention results for gpt2...
# 	Loaded ../summaries/gpt2.csv with 900 summaries.
# 	Shifted left: 0.33111111111111113
# 	Shifted right: 0.22555555555555556
# 	Shifted center: 0.44333333333333336
# Processing no intervention results for neo...
# 	Loaded ../summaries/neo.csv with 900 summaries.
# 	Shifted left: 0.37222222222222223
# 	Shifted right: 0.21
# 	Shifted center: 0.4177777777777778
# Processing no intervention results for llama...
# 	Loaded ../summaries/llama.csv with 900 summaries.
# 	Shifted left: 0.32666666666666666
# 	Shifted right: 0.3011111111111111
# 	Shifted center: 0.37222222222222223

# %%
for model in ['bart', 't5', 'gpt2', 'neo', 'llama']:
    process_summaries(model)
# Out:
# Processing summaries for bart...
# 	Loaded ../summaries/bart.csv with 900 summaries.
# 	Loaded ../summaries/bart-prompt.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.4022222222222222
#  - PBF score without steering: 0.5253656378033953
#
#
#  - percentage matching with steering (ALL): 0.3388888888888889
#  - PBF score with steering (ALL): 0.45993827513267826
# 	 - percentage matching with steering (LEFT): 0.17222222222222222
# 	 - PBF score with steering (LEFT): 0.3295938212960412
# 	 - percentage matching with steering (CENTER): 0.5166666666666667
# 	 - PBF score with steering (CENTER): 0.6523891064230964
# 	 - percentage matching with steering (RIGHT): 0.3277777777777778
# 	 - PBF score with steering (RIGHT): 0.44798349461069353
#
#
#  - PBF score with steering, where target bias matches source bias: 0.5283009433971698
#  - PBF score with steering, where target bias does *not* match source bias: 0.5272715132105723
#
# --------------------
#
# Processing summaries for t5...
# 	Loaded ../summaries/t5.csv with 900 summaries.
# 	Loaded ../summaries/t5-prompt.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.3022222222222222
#  - PBF score without steering: 0.423131056670774
#
#
#  - percentage matching with steering (ALL): 0.3288888888888889
#  - PBF score with steering (ALL): 0.3871741229716589
# 	 - percentage matching with steering (LEFT): 0.54
# 	 - PBF score with steering (LEFT): 0.4321091654199727
# 	 - percentage matching with steering (CENTER): 0.19
# 	 - PBF score with steering (CENTER): 0.55
# 	 - percentage matching with steering (RIGHT): 0.25666666666666665
# 	 - PBF score with steering (RIGHT): 0.22432824811866026
#
#
#  - PBF score with steering, where target bias matches source bias: 0.42820944005305195
#  - PBF score with steering, where target bias does *not* match source bias: 0.4493690487772737
#
# --------------------
#
# Processing summaries for gpt2...
# 	Loaded ../summaries/gpt2.csv with 900 summaries.
# 	Loaded ../summaries/gpt2-prompt.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.44333333333333336
#  - PBF score without steering: 0.544478321042785
#
#
#  - percentage matching with steering (ALL): 0.3414814814814815
#  - PBF score with steering (ALL): 0.5039974611773459
# 	 - percentage matching with steering (LEFT): 0.24222222222222223
# 	 - PBF score with steering (LEFT): 0.5047447347298792
# 	 - percentage matching with steering (CENTER): 0.6866666666666666
# 	 - PBF score with steering (CENTER): 0.7201190729375555
# 	 - percentage matching with steering (RIGHT): 0.09555555555555556
# 	 - PBF score with steering (RIGHT): 0.3562264028057345
#
#
#  - PBF score with steering, where target bias matches source bias: 0.5577833612859467
#  - PBF score with steering, where target bias does *not* match source bias: 0.5532524948773263
#
# --------------------
#
# Processing summaries for neo...
# 	Loaded ../summaries/neo.csv with 900 summaries.
# 	Loaded ../summaries/neo-prompt.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.4177777777777778
#  - PBF score without steering: 0.5420456111988639
#
#
#  - percentage matching with steering (ALL): 0.337037037037037
#  - PBF score with steering (ALL): 0.48020659374595254
# 	 - percentage matching with steering (LEFT): 0.31222222222222223
# 	 - PBF score with steering (LEFT): 0.4841404153152613
# 	 - percentage matching with steering (CENTER): 0.5822222222222222
# 	 - PBF score with steering (CENTER): 0.6768213428389114
# 	 - percentage matching with steering (RIGHT): 0.11666666666666667
# 	 - PBF score with steering (RIGHT): 0.33667504192892006
#
#
#  - PBF score with steering, where target bias matches source bias: 0.5426525755329252
#  - PBF score with steering, where target bias does *not* match source bias: 0.5501543474578074
#
# --------------------
#
# Processing summaries for llama...
# 	Loaded ../summaries/llama.csv with 900 summaries.
# 	Loaded ../summaries/llama-prompt.csv with 2700 summaries.
#
#
#  - percentage matching with steering: 0.37222222222222223
#  - PBF score without steering: 0.5288901991632478
#
#
#  - percentage matching with steering (ALL): 0.34814814814814815
#  - PBF score with steering (ALL): 0.4546492803640877
# 	 - percentage matching with steering (LEFT): 0.31555555555555553
# 	 - PBF score with steering (LEFT): 0.4060490106264847
# 	 - percentage matching with steering (CENTER): 0.5155555555555555
# 	 - PBF score with steering (CENTER): 0.651989783036315
# 	 - percentage matching with steering (RIGHT): 0.21333333333333335
# 	 - PBF score with steering (RIGHT): 0.3532130696022582
#
#
#  - PBF score with steering, where target bias matches source bias: 0.5047447347298791
#  - PBF score with steering, where target bias does *not* match source bias: 0.5040441327877829
#
# --------------------
